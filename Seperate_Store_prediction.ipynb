# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")
df['date'] = pd.to_datetime(df['date'])

# %%
df1 = df[df.store == 1]
df2 = df[df.store == 2]
df3 = df[df.store == 3]
df4 = df[df.store == 4]
df5 = df[df.store == 5]
df6 = df[df.store == 6]
df7 = df[df.store == 7]
df8 = df[df.store == 8]
df9 = df[df.store == 9]
df10 = df[df.store == 10]

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
print(df6.shape)
print(df7.shape)
print(df8.shape)
print(df9.shape)
print(df10.shape)
# Out:
# (91300, 4)
# (91300, 4)
# (91300, 4)
# (91300, 4)
# (91300, 4)
# (91300, 4)
# (91300, 4)
# (91300, 4)
# (91300, 4)
# (91300, 4)

# %%
df1 = df1.drop(['store'], axis = 1)
df2 = df2.drop(['store'], axis = 1)
df3 = df3.drop(['store'], axis = 1)
df4 = df4.drop(['store'], axis = 1)
df5 = df5.drop(['store'], axis = 1)
df6 = df6.drop(['store'], axis = 1)
df7 = df7.drop(['store'], axis = 1)
df8 = df8.drop(['store'], axis = 1)
df9 = df9.drop(['store'], axis = 1)
df10 = df10.drop(['store'], axis = 1)

# %%
df1 = df1.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df2 = df2.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df3 = df3.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df4 = df4.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df5 = df5.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df6 = df6.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df7 = df7.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df8 = df8.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df9 = df9.groupby(['date', 'item'])['sales'].aggregate('first').unstack()
df10 = df10.groupby(['date', 'item'])['sales'].aggregate('first').unstack()

# %%
df1 = df1.reset_index()
df2 = df2.reset_index()
df3 = df3.reset_index()
df4 = df4.reset_index()
df5 = df5.reset_index()
df6 = df6.reset_index()
df7 = df7.reset_index()
df8 = df8.reset_index()
df9 = df9.reset_index()
df10 = df10.reset_index()

# %%
df1.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df2.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df3.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df4.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df5.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df6.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df7.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df8.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df9.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']
df10.columns = ['DATE', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10',
               'I11', 'I12', 'I13', 'I14', 'I15', 'I16', 'I17', 'I18', 'I19', 'I20',
               'I21', 'I22', 'I23', 'I24', 'I25', 'I26', 'I27', 'I28', 'I29', 'I30',
               'I31', 'I32', 'I33', 'I34', 'I35', 'I36', 'I37', 'I38', 'I39', 'I40',
               'I41', 'I42', 'I43', 'I44', 'I45', 'I46', 'I47', 'I48', 'I49', 'I50']

# %%
df_1 = df1[['DATE', 'I1', 'I2', 'I3']]
df_2 = df2[['DATE', 'I1', 'I2', 'I3']]
df_3 = df3[['DATE', 'I1', 'I2', 'I3']]

# %%
df1 = df_1.set_index(['DATE'], drop=True)
df2 = df_2.set_index(['DATE'], drop=True)
df3 = df_3.set_index(['DATE'], drop=True)

# %%
df1.shape
# Out:
# (1826, 3)

# %%
plt.figure(figsize=(12,5));
plt.title("Sales of item 1 for store 1", fontsize = 20, weight = "bold");
plt.plot(df1['I1']);
plt.legend();
plt.xlabel('Date', fontsize = 15, weight = "bold");
plt.ylabel('Sales', fontsize = 15, weight = "bold");
plt.savefig("Sales_of_i1_for_s1.png");

# %%
plt.figure(figsize=(12,5));
plt.title("Sales for store 1 for first three items", fontsize = 20, weight = "bold");
plt.plot(df1)
plt.gca().legend(('I1','I2', 'I3'))
plt.xlabel('Date', fontsize = 15, weight = "bold");
plt.ylabel('Sales', fontsize = 15, weight = "bold");
plt.savefig("Sales_of_s1.png");

# %%
plt.figure(figsize=(12,5));
plt.title("Sales for store 2 for first three items", fontsize = 20, weight = "bold");
plt.plot(df2)
plt.gca().legend(('I1','I2', 'I3'))
plt.xlabel('Date', fontsize = 15, weight = "bold");
plt.ylabel('Sales', fontsize = 15, weight = "bold");
plt.savefig("Sales_of_s2.png");

# %%
plt.figure(figsize=(12,5));
plt.title("Sales for store 3 for first three items", fontsize = 20, weight = "bold");
plt.plot(df3)
plt.gca().legend(('I1','I2', 'I3'))
plt.xlabel('Date', fontsize = 15, weight = "bold");
plt.ylabel('Sales', fontsize = 15, weight = "bold");
plt.savefig("Sales_of_s3.png");

# %%
df = df_1[['DATE', 'I1']]
df['S2_I1'] = df_2['I1']
df['S3_I1'] = df_3['I1']
df.columns = ['DATE', 'S1_I1', 'S2_I1', 'S3_I1']
df = df.set_index(['DATE'], drop=True)
# Out:
# C:\Users\ashu1\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.figure(figsize=(12,5));
plt.title("Sales for item 1 in first three stores", fontsize = 20, weight = "bold");
plt.plot(df)
plt.gca().legend(('S1','S2', 'S3'))
plt.xlabel('Date', fontsize = 15, weight = "bold");
plt.ylabel('Sales', fontsize = 15, weight = "bold");
plt.savefig("Sales_of_i1.png");
